# %%
print("<---------Start--------->")

import os
os.chdir(r'C:\Users\Admin\Desktop\My Tree\Analysis\Gautam_KeyWord_Funnel_Analysis\#3_Final_Camp_Name_Making\Corrected')
#os.chdir('/home/ubuntu/da/Google_Keywords')
import pandas as pd

print("PWD set")

lst1= pd.read_csv("Input_Data_KeyTerms.csv",encoding = "ISO-8859-1")
lst2= pd.read_csv("To_Replace_With.csv",encoding = "ISO-8859-1")

lst_temp = lst2[lst2['Cuts'].str.contains("Job Category")]
lst_temp2 = lst_temp[lst_temp.columns[1]]
lst_Job_Category = list(lst_temp2)

lst_temp = lst2[lst2['Cuts'].str.contains("City")]
lst_temp2 = lst_temp[lst_temp.columns[1]]
lst_City = list(lst_temp2)

lst_temp = lst2[lst2['Cuts'].str.contains("Competitor List")]
lst_temp2 = lst_temp[lst_temp.columns[1]]
lst_Competitor_List = list(lst_temp2)

lst_temp = lst2[lst2['Cuts'].str.contains("Gender")]
lst_temp2 = lst_temp[lst_temp.columns[1]]
lst_Gender = list(lst_temp2)

lst_temp = lst2[lst2['Cuts'].str.contains("Location")]
lst_temp2 = lst_temp[lst_temp.columns[1]]
lst_Location = list(lst_temp2)

lst_temp = lst2[lst2['Cuts'].str.contains("Qualification")]
lst_temp2 = lst_temp[lst_temp.columns[1]]
lst_Qualification = list(lst_temp2)


lst_temp = lst2[lst2['Cuts'].str.contains("Store Type")]
lst_temp2 = lst_temp[lst_temp.columns[1]]
lst_Store_Type = list(lst_temp2)


lst_temp = lst2[lst2['Cuts'].str.contains("Job Type")]
lst_temp2 = lst_temp[lst_temp.columns[1]]
lst_Job_Type = list(lst_temp2)


print("List for Cuts Created")


print("Start ---> lst_Job_Category")

##### 1   <<<<-----lst_Job_Category

replaced_list =[]
Part_Of_The_Sheet =[]
Match_Type =[]
Funnel_Stage =[]
Theme = []

lst_temp_yes = lst1[lst1['Match Pattern'].str.contains("<Job Category>")]#<--chaneg here
lst_temp_no = lst1[~lst1['Match Pattern'].str.contains("<Job Category>")]#<--chaneg here

print("Lenght of The df : ",len(lst1))
print("Lenght of The df to replace : ",len(lst_temp_yes))
print("Lenght of The df NOT to replace : ",len(lst_temp_no))
print("Lenght of The df to be replaced by : ",len(lst_Job_Category))

for i in range(0,len(lst_Job_Category)):#<--chaneg here
    for j in range(0,len(lst_temp_yes)):#<----Change here
        to_replace_with = (lst_Job_Category[i])#<--chaneg here
        to_replace_in = (lst_temp_yes.iloc[j][1])
        Part_Of_The_Sheet_string = (lst_temp_yes.iloc[j][0])
        Match_Type_string = (lst_temp_yes.iloc[j][2])
        Funnel_Stage_string = (lst_temp_yes.iloc[j][3])
        Theme_String = (lst_temp_yes.iloc[j][4])
        replaced = to_replace_in.replace("<Job Category>",str(to_replace_with))
        replaced_list.append(replaced)
        Part_Of_The_Sheet.append(Part_Of_The_Sheet_string)
        Match_Type.append(Match_Type_string)
        Funnel_Stage.append(Funnel_Stage_string)
        Theme.append(Theme_String)

df = pd.DataFrame(list(zip(Part_Of_The_Sheet,replaced_list,Match_Type,Funnel_Stage,Theme)), 
               columns =['Part_Of_The_Sheet', 'Match Pattern','Match Type','Funnel Stage','Theme'])

df_final = df.append(lst_temp_no)#<--chaneg here


print("End ---> lst_Job_Category")


##### 2   <<<<-----lst_Job_Type

print("Start ---> lst_Job_Type")

replaced_list =[]
Part_Of_The_Sheet =[]
Match_Type =[]
Funnel_Stage =[]
Theme = []

lst_temp_yes = df_final[df_final['Match Pattern'].str.contains("<Job Type>")]#<--chaneg here
lst_temp_no = df_final[~df_final['Match Pattern'].str.contains("<Job Type>")]#<--chaneg here

print("Lenght of The df : ",len(df_final))
print("Lenght of The df to replace : ",len(lst_temp_yes))
print("Lenght of The df NOT to replace : ",len(lst_temp_no))
print("Lenght of The df to be replaced by : ",len(lst_Job_Type))



for i in range(0,len(lst_Job_Type)):#<--chaneg here
    for j in range(0,len(lst_temp_yes)):
        to_replace_with = (lst_Job_Type[i])#<--chaneg here
        to_replace_in = (lst_temp_yes.iloc[j][1])
        Part_Of_The_Sheet_string = (lst_temp_yes.iloc[j][0])
        Match_Type_string = (lst_temp_yes.iloc[j][2])
        Funnel_Stage_string = (lst_temp_yes.iloc[j][3])
        Theme_String = (lst_temp_yes.iloc[j][4])
        replaced = to_replace_in.replace("<Job Type>",str(to_replace_with))#<---Change here
        replaced_list.append(replaced)
        Part_Of_The_Sheet.append(Part_Of_The_Sheet_string)
        Match_Type.append(Match_Type_string)
        Funnel_Stage.append(Funnel_Stage_string)
        Theme.append(Theme_String)

df = pd.DataFrame(list(zip(Part_Of_The_Sheet,replaced_list,Match_Type,Funnel_Stage,Theme)), 
               columns =['Part_Of_The_Sheet', 'Match Pattern','Match Type','Funnel Stage','Theme'])

df_final = df.append(lst_temp_no)

print("End ---> lst_Job_Type")
print("Lenght of The df : ",len(df_final))

##### 4   <<<<-----lst_Competitor_List

print("Start ---> lst_Competitor_List")

replaced_list =[]
Part_Of_The_Sheet =[]
Match_Type =[]
Funnel_Stage =[]
Theme = []

lst_temp_yes = df_final[df_final['Match Pattern'].str.contains("<Competitor>")]#<--chaneg here
lst_temp_no = df_final[~df_final['Match Pattern'].str.contains("<Competitor>")]#<--chaneg here

print("Lenght of The df : ",len(df_final))
print("Lenght of The df to replace : ",len(lst_temp_yes))
print("Lenght of The df NOT to replace : ",len(lst_temp_no))
print("Lenght of The df to be replaced by : ",len(lst_Competitor_List))

for i in range(0,len(lst_Competitor_List)):#<--chaneg here
    for j in range(0,len(lst_temp_yes)):
        to_replace_with = (lst_Competitor_List[i])#<--chaneg here
        to_replace_in = (lst_temp_yes.iloc[j][1])
        Part_Of_The_Sheet_string = (lst_temp_yes.iloc[j][0])
        Match_Type_string = (lst_temp_yes.iloc[j][2])
        Funnel_Stage_string = (lst_temp_yes.iloc[j][3])
        Theme_String = (lst_temp_yes.iloc[j][4])
        replaced = to_replace_in.replace("<Competitor>",str(to_replace_with))#<---Change here
        replaced_list.append(replaced)
        Part_Of_The_Sheet.append(Part_Of_The_Sheet_string)
        Match_Type.append(Match_Type_string)
        Funnel_Stage.append(Funnel_Stage_string)
        Theme.append(Theme_String)

df = pd.DataFrame(list(zip(Part_Of_The_Sheet,replaced_list,Match_Type,Funnel_Stage,Theme)), 
               columns =['Part_Of_The_Sheet', 'Match Pattern','Match Type','Funnel Stage','Theme'])

df_final = df.append(lst_temp_no)

print("End ---> lst_Competitor_List")
print("Lenght of The df : ",len(df_final))

##### 5   <<<<-----lst_Gender

print("Start ---> lst_Gender")

replaced_list =[]
Part_Of_The_Sheet =[]
Match_Type =[]
Funnel_Stage =[]
Theme = []

lst_temp_yes = df_final[df_final['Match Pattern'].str.contains("<Gender>")]#<--chaneg here
lst_temp_no = df_final[~df_final['Match Pattern'].str.contains("<Gender>")]#<--chaneg here

print("Lenght of The df : ",len(df_final))
print("Lenght of The df to replace : ",len(lst_temp_yes))
print("Lenght of The df NOT to replace : ",len(lst_temp_no))
print("Lenght of The df to be replaced by : ",len(lst_Gender))


for i in range(0,len(lst_Gender)):#<--chaneg here
    for j in range(0,len(lst_temp_yes)):
        to_replace_with = (lst_Gender[i])#<--chaneg here
        to_replace_in = (lst_temp_yes.iloc[j][1])
        Part_Of_The_Sheet_string = (lst_temp_yes.iloc[j][0])
        Match_Type_string = (lst_temp_yes.iloc[j][2])
        Funnel_Stage_string = (lst_temp_yes.iloc[j][3])
        Theme_String = (lst_temp_yes.iloc[j][4])
        replaced = to_replace_in.replace("<Gender>",str(to_replace_with))#<---Change here
        replaced_list.append(replaced)
        Part_Of_The_Sheet.append(Part_Of_The_Sheet_string)
        Match_Type.append(Match_Type_string)
        Funnel_Stage.append(Funnel_Stage_string)
        Theme.append(Theme_String)

df = pd.DataFrame(list(zip(Part_Of_The_Sheet,replaced_list,Match_Type,Funnel_Stage,Theme)), 
               columns =['Part_Of_The_Sheet', 'Match Pattern','Match Type','Funnel Stage','Theme'])

df_final = df.append(lst_temp_no)

print("End ---> lst_Gender")
print("Lenght of The df : ",len(df_final))

##### 6   <<<<-----lst_Qualification

print("Start ---> lst_Qualification")

replaced_list =[]
Part_Of_The_Sheet =[]
Match_Type =[]
Funnel_Stage =[]
Theme = []
lst_temp_yes = df_final[df_final['Match Pattern'].str.contains("<Qualification>")]#<--chaneg here
lst_temp_no = df_final[~df_final['Match Pattern'].str.contains("<Qualification>")]#<--chaneg here

print("Lenght of The df : ",len(df_final))
print("Lenght of The df to replace : ",len(lst_temp_yes))
print("Lenght of The df NOT to replace : ",len(lst_temp_no))
print("Lenght of The df to be replaced by : ",len(lst_Qualification))

for i in range(0,len(lst_Qualification)):#<--chaneg here
    for j in range(0,len(lst_temp_yes)):
        to_replace_with = (lst_Qualification[i])#<--chaneg here
        to_replace_in = (lst_temp_yes.iloc[j][1])
        Part_Of_The_Sheet_string = (lst_temp_yes.iloc[j][0])
        Match_Type_string = (lst_temp_yes.iloc[j][2])
        Funnel_Stage_string = (lst_temp_yes.iloc[j][3])
        Theme_String = (lst_temp_yes.iloc[j][4])
        replaced = to_replace_in.replace("<Qualification>",str(to_replace_with))#<---Change here
        replaced_list.append(replaced)
        Part_Of_The_Sheet.append(Part_Of_The_Sheet_string)
        Match_Type.append(Match_Type_string)
        Funnel_Stage.append(Funnel_Stage_string)
        Theme.append(Theme_String)

df = pd.DataFrame(list(zip(Part_Of_The_Sheet,replaced_list,Match_Type,Funnel_Stage,Theme)), 
               columns =['Part_Of_The_Sheet', 'Match Pattern','Match Type','Funnel Stage','Theme'])

df_final = df.append(lst_temp_no)

print("End ---> lst_Qualification")
print("Lenght of The df : ",len(df_final))


##### 6   <<<<-----lst_Store_Type

print("Start ---> lst_Store_Type")

replaced_list =[]
Part_Of_The_Sheet =[]
Match_Type =[]
Funnel_Stage =[]
Theme = []
lst_temp_yes = df_final[df_final['Match Pattern'].str.contains("<Store Type>")]#<--chaneg here
lst_temp_no = df_final[~df_final['Match Pattern'].str.contains("<Store Type>")]#<--chaneg here

print("Lenght of The df : ",len(df_final))
print("Lenght of The df to replace : ",len(lst_temp_yes))
print("Lenght of The df NOT to replace : ",len(lst_temp_no))
print("Lenght of The df to be replaced by : ",len(lst_Store_Type))

for i in range(0,len(lst_Store_Type)):#<--chaneg here
    for j in range(0,len(lst_temp_yes)):
        to_replace_with = (lst_Store_Type[i])#<--chaneg here
        to_replace_in = (lst_temp_yes.iloc[j][1])
        Part_Of_The_Sheet_string = (lst_temp_yes.iloc[j][0])
        Match_Type_string = (lst_temp_yes.iloc[j][2])
        Funnel_Stage_string = (lst_temp_yes.iloc[j][3])
        Theme_String = (lst_temp_yes.iloc[j][4])
        replaced = to_replace_in.replace("<Store Type>",str(to_replace_with))#<---Change here
        replaced_list.append(replaced)
        Part_Of_The_Sheet.append(Part_Of_The_Sheet_string)
        Match_Type.append(Match_Type_string)
        Funnel_Stage.append(Funnel_Stage_string)
        Theme.append(Theme_String)

df = pd.DataFrame(list(zip(Part_Of_The_Sheet,replaced_list,Match_Type,Funnel_Stage,Theme)), 
               columns =['Part_Of_The_Sheet', 'Match Pattern','Match Type','Funnel Stage','Theme'])

df_final = df.append(lst_temp_no)

print("End ---> lst_Store_Type")
print("Lenght of The df : ",len(df_final))

####################################################################################
##### 3   <<<<-----lst_City

print("Start ---> lst_City")

replaced_list =[]
Part_Of_The_Sheet =[]
Match_Type =[]
Funnel_Stage =[]
Theme= []

lst_temp_yes = df_final[df_final['Match Pattern'].str.contains("<Location>")]#<--chaneg here
lst_temp_no = df_final[~df_final['Match Pattern'].str.contains("<Location>")]#<--chaneg here

print("Lenght of The df : ",len(df_final))
print("Lenght of The df to replace : ",len(lst_temp_yes))
print("Lenght of The df NOT to replace : ",len(lst_temp_no))
print("Lenght of The df to be replaced by : ",len(lst_City))


for i in range(0,len(lst_City)):#<--chaneg here
    for j in range(0,len(lst_temp_yes)):
        to_replace_with = (lst_City[i])#<--chaneg here
        to_replace_in = (lst_temp_yes.iloc[j][1])
        Part_Of_The_Sheet_string = (lst_temp_yes.iloc[j][0])
        Match_Type_string = (lst_temp_yes.iloc[j][2])
        Funnel_Stage_string = (lst_temp_yes.iloc[j][3])
        Theme_String = (lst_temp_yes.iloc[j][4])
        replaced = to_replace_in.replace("<Location>",str(to_replace_with))#<---Change here
        replaced_list.append(replaced)
        Part_Of_The_Sheet.append(Part_Of_The_Sheet_string)
        Match_Type.append(Match_Type_string)
        Funnel_Stage.append(Funnel_Stage_string)
        Theme.append(Theme_String)

df_1 = pd.DataFrame(list(zip(Part_Of_The_Sheet,replaced_list,Match_Type,Funnel_Stage,Theme)), 
               columns =['Part_Of_The_Sheet', 'Match Pattern','Match Type','Funnel Stage','Theme'])

df_final_1 = df_1.append(lst_temp_no)

####################################################################################################
##### 3   <<<<-----lst_Location

print("Start ---> lst_Location")

replaced_list =[]
Part_Of_The_Sheet =[]
Match_Type =[]
Funnel_Stage =[]
Theme= []

lst_temp_yes = df_final[df_final['Match Pattern'].str.contains("<Location>")]#<--chaneg here
lst_temp_no = df_final[~df_final['Match Pattern'].str.contains("<Location>")]#<--chaneg here

print("Lenght of The df : ",len(df_final))
print("Lenght of The df to replace : ",len(lst_temp_yes))
print("Lenght of The df NOT to replace : ",len(lst_temp_no))
print("Lenght of The df to be replaced by : ",len(lst_Location))


for i in range(0,len(lst_Location)):#<--chaneg here
    for j in range(0,len(lst_temp_yes)):
        to_replace_with = (lst_Location[i])#<--chaneg here
        to_replace_in = (lst_temp_yes.iloc[j][1])
        Part_Of_The_Sheet_string = (lst_temp_yes.iloc[j][0])
        Match_Type_string = (lst_temp_yes.iloc[j][2])
        Funnel_Stage_string = (lst_temp_yes.iloc[j][3])
        Theme_String = (lst_temp_yes.iloc[j][4])
        replaced = to_replace_in.replace("<Location>",str(to_replace_with))#<---Change here
        replaced_list.append(replaced)
        Part_Of_The_Sheet.append(Part_Of_The_Sheet_string)
        Match_Type.append(Match_Type_string)
        Funnel_Stage.append(Funnel_Stage_string)
        Theme.append(Theme_String)

df_2 = pd.DataFrame(list(zip(Part_Of_The_Sheet,replaced_list,Match_Type,Funnel_Stage,Theme)), 
               columns =['Part_Of_The_Sheet', 'Match Pattern','Match Type','Funnel Stage','Theme'])

df_final_2 = df_2.append(lst_temp_no)


df_final = df_final_2.append(df_final_1)




print("End ---> lst_City")


print("Lenght of The df : ",len(df_final))



print("Saving the DF to CSV")

df_final.to_csv("Google_Ex_Keywords.csv", index = False)

print("Saved!")

print("<---------The End--------->")
# Out:
# <---------Start--------->
# PWD set
# List for Cuts Created
# Start ---> lst_Job_Category
# Lenght of The df :  900
# Lenght of The df to replace :  203
# Lenght of The df NOT to replace :  697
# Lenght of The df to be replaced by :  74
# End ---> lst_Job_Category
# Start ---> lst_Job_Type
# Lenght of The df :  15719
# Lenght of The df to replace :  246
# Lenght of The df NOT to replace :  15473
# Lenght of The df to be replaced by :  2
# End ---> lst_Job_Type
# Lenght of The df :  15965
# Start ---> lst_Competitor_List
# Lenght of The df :  15965
# Lenght of The df to replace :  362
# Lenght of The df NOT to replace :  15603
# Lenght of The df to be replaced by :  8
# End ---> lst_Competitor_List
# Lenght of The df :  18499
# Start ---> lst_Gender
# Lenght of The df :  18499
# Lenght of The df to replace :  378
# Lenght of The df NOT to replace :  18121
# Lenght of The df to be replaced by :  2
# End ---> lst_Gender
# Lenght of The df :  18877
# Start ---> lst_Qualification
# ...

# %%
# Out:
# Saving the DF to CSV
# Saved!
# <---------The End--------->
